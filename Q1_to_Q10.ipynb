# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitbourasi0/30-Days-of-Pandas-Solution-Leetcode/blob/main/Q1_to_Q10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **595. Big Countries**

# %%
data = [['Afghanistan', 'Asia', 652230, 25500100, 20343000000], ['Albania', 'Europe', 28748, 2831741, 12960000000], ['Algeria', 'Africa', 2381741, 37100000, 188681000000], ['Andorra', 'Europe', 468, 78115, 3712000000], ['Angola', 'Africa', 1246700, 20609294, 100990000000]]
world = pd.DataFrame(data, columns=['name', 'continent', 'area', 'population', 'gdp']).astype({'name':'object', 'continent':'object', 'area':'Int64', 'population':'Int64', 'gdp':'Int64'})

# %%
world
# Out:
#           name continent     area  population           gdp
# 0  Afghanistan      Asia   652230    25500100   20343000000
# 1      Albania    Europe    28748     2831741   12960000000
# 2      Algeria    Africa  2381741    37100000  188681000000
# 3      Andorra    Europe      468       78115    3712000000
# 4       Angola    Africa  1246700    20609294  100990000000

# %%
bigCountries = world[(world["area"] >= 3000000) | (world["population"]>=25000000)][["name","population","area"]]
bigCountries
# Out:
#           name  population     area
# 0  Afghanistan    25500100   652230
# 2      Algeria    37100000  2381741

# %% [markdown]
# **1757. Recyclable and Low Fat Products**

# %%
data = [['0', 'Y', 'N'],['1', 'Y', 'Y'], ['2', 'N', 'Y'], ['3', 'Y', 'Y'], ['4', 'N', 'N']]
products = pd.DataFrame(data, columns=['product_id', 'low_fats', 'recyclable']).astype({'product_id':'int64', 'low_fats':'category', 'recyclable':'category'})

# %%
products
# Out:
#    product_id low_fats recyclable
# 0           0        Y          N
# 1           1        Y          Y
# 2           2        N          Y
# 3           3        Y          Y
# 4           4        N          N

# %%
products[(products["low_fats"]=="Y") & (products["recyclable"] == "Y")][["product_id"]]
# Out:
#    product_id
# 1           1
# 3           3

# %% [markdown]
# **183. Customers Who Never Order**

# %%
data = [[1, 'Joe'], [2, 'Henry'], [3, 'Sam'], [4, 'Max']]
customers = pd.DataFrame(data, columns=['id', 'name']).astype({'id':'Int64', 'name':'object'})
data = [[1, 3], [2, 1]]
orders = pd.DataFrame(data, columns=['id', 'customerId']).astype({'id':'Int64', 'customerId':'Int64'})

# %%
customers
# Out:
#    id   name
# 0   1    Joe
# 1   2  Henry
# 2   3    Sam
# 3   4    Max

# %%
orders
# Out:
#    id  customerId
# 0   1           3
# 1   2           1

# %%
result = customers[~customers["id"].isin(orders["customerId"])][["name"]]

# %%
result.rename(columns={"name":"Customers"})
# Out:
#   Customers
# 1     Henry
# 3       Max

# %% [markdown]
# **1148. Article Views I**

# %%
data = [[1, 3, 5, '2019-08-01'], [1, 3, 6, '2019-08-02'], [2, 7, 7, '2019-08-01'], [2, 7, 6, '2019-08-02'], [4, 7, 1, '2019-07-22'], [3, 4, 4, '2019-07-21'], [3, 4, 4, '2019-07-21']]
views = pd.DataFrame(data, columns=['article_id', 'author_id', 'viewer_id', 'view_date']).astype({'article_id':'Int64', 'author_id':'Int64', 'viewer_id':'Int64', 'view_date':'datetime64[ns]'})

# %%
views
# Out:
#    article_id  author_id  viewer_id  view_date
# 0           1          3          5 2019-08-01
# 1           1          3          6 2019-08-02
# 2           2          7          7 2019-08-01
# 3           2          7          6 2019-08-02
# 4           4          7          1 2019-07-22
# 5           3          4          4 2019-07-21
# 6           3          4          4 2019-07-21

# %%
filter = views[views["author_id"] == views["viewer_id"]]

# %%
result = filter["author_id"].unique()

# %%
authors = sorted(result)

# %%
result_df = pd.DataFrame({"id":authors})
result_df
# Out:
#    id
# 0   4
# 1   7

# %% [markdown]
# **1683. Invalid Tweets**

# %%
data = [[1, 'Vote for Biden'], [2, 'Let us make America great again!']]
tweets = pd.DataFrame(data, columns=['tweet_id', 'content']).astype({'tweet_id':'Int64', 'content':'object'})

# %%
tweets[tweets["content"].str.len() > 15][["tweet_id"]]
# Out:
#    tweet_id
# 1         2

# %% [markdown]
# **619. Biggest Single Number**

# %%
data = [[8], [8], [3], [3], [1], [4], [5], [6]]
my_numbers = pd.DataFrame(data, columns=['num']).astype({'num':'Int64'})

# %%
my_numbers
# Out:
#    num
# 0    8
# 1    8
# 2    3
# 3    3
# 4    1
# 5    4
# 6    5
# 7    6

# %%
#drop_duplicates consider only duplicates elements and pass non duplicates
my_numbers.drop_duplicates(keep = False).max().to_frame(name='num')
# Out:
#      num
# num    6

# %% [markdown]
# **1873. Calculate Special Bonus**

# %%
data = [[2, 'Meir', 3000], [3, 'Michael', 3800], [7, 'Addilyn', 7400], [8, 'Juan', 6100], [9, 'Kannon', 7700]]
employees = pd.DataFrame(data, columns=['employee_id', 'name', 'salary']).astype({'employee_id':'int64', 'name':'object', 'salary':'int64'})

# %%
employees
# Out:
#    employee_id     name  salary
# 0            2     Meir    3000
# 1            3  Michael    3800
# 2            7  Addilyn    7400
# 3            8     Juan    6100
# 4            9   Kannon    7700

# %%
#True means 1 False means 0, If ANY  x * TRUE return x , if x * False return 0
employees["bonus"] = ((employees["employee_id"] % 2 != 0) & (~employees["name"].str.startswith("M")))*employees["salary"]

# %%
employees = employees.sort_values(by="employee_id")

# %%
employees[["employee_id","bonus"]]
# Out:
#    employee_id  bonus
# 0            2      0
# 1            3      0
# 2            7   7400
# 3            8      0
# 4            9   7700

# %% [markdown]
# **1667. Fix Names in a Table**
# **bold text**

# %%
data = [[1, 'aLice'], [2, 'bOB']]
users = pd.DataFrame(data, columns=['user_id', 'name']).astype({'user_id':'Int64', 'name':'object'})

# %%
users
# Out:
#    user_id   name
# 0        1  aLice
# 1        2    bOB

# %%
# use str each time because each function return series so after that we have to apply str function each time
users["name"] = users["name"].str.capitalize().str.strip()

# %%
users = users.sort_values(by="user_id")
users
# Out:
#    user_id   name
# 0        1  Alice
# 1        2    Bob

# %% [markdown]
# **1517. Find Users With Valid E-Mails**
# **bold text**

# %%
data = [[1, 'Winston', 'winston@leetcode.com'], [2, 'Jonathan', 'jonathanisgreat'], [3, 'Annabelle', 'bella-@leetcode.com'], [4, 'Sally', 'sally.come@leetcode.com'], [5, 'Marwan', 'quarz#2020@leetcode.com'], [6, 'David', 'david69@gmail.com'], [7, 'Shapiro', '.shapo@leetcode.com']]
users = pd.DataFrame(data, columns=['user_id', 'name', 'mail']).astype({'user_id':'int64', 'name':'object', 'mail':'object'})

# %%
users
# Out:
#    user_id       name                     mail
# 0        1    Winston     winston@leetcode.com
# 1        2   Jonathan          jonathanisgreat
# 2        3  Annabelle      bella-@leetcode.com
# 3        4      Sally  sally.come@leetcode.com
# 4        5     Marwan  quarz#2020@leetcode.com
# 5        6      David        david69@gmail.com
# 6        7    Shapiro      .shapo@leetcode.com

# %%
'''
direct apply regex using match function
[] = characters contains
a-z , A-Z = all small and Capital letters
^ = start with
$ = end with
\. = .
\- = -
0-9 = all digits
* = split after this

'''
valid_email = users[users["mail"].str.match(r'^[a-zA-Z][a-zA-Z0-9_\.\-]*@leetcode(\?com)?\.com$')]
valid_email
# Out:
#    user_id       name                     mail
# 0        1    Winston     winston@leetcode.com
# 2        3  Annabelle      bella-@leetcode.com
# 3        4      Sally  sally.come@leetcode.com

# %% [markdown]
# **1527. Patients With a Condition**

# %%
data = [[1, 'Daniel', 'YFEV COUGH'], [2, 'Alice', ''], [3, 'Bob', 'DIAB100 MYOP'], [4, 'George', 'ACNE DIAB100'], [5, 'Alain', 'DIAB201']]
patients = pd.DataFrame(data, columns=['patient_id', 'patient_name', 'conditions']).astype({'patient_id':'int64', 'patient_name':'object', 'conditions':'object'})

# %%
patients
# Out:
#    patient_id patient_name    conditions
# 0           1       Daniel    YFEV COUGH
# 1           2        Alice
# 2           3          Bob  DIAB100 MYOP
# 3           4       George  ACNE DIAB100
# 4           5        Alain       DIAB201

# %%
# \b  stand for boundaries
# \bDIAB1\b start to end with DIAB1
patients[patients["conditions"].str.contains(r"\bDIAB1",regex=True)]
# Out:
#    patient_id patient_name    conditions
# 2           3          Bob  DIAB100 MYOP
# 3           4       George  ACNE DIAB100

# %%
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
# [main (root-commit) 20d32f2] Initialize
#  20 files changed, 50872 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/default_configs.db
#  create mode 100644 .config/gce
#  create mode 100644 .config/logs/2023.09.13/13.21.06.140302.log
#  create mode 100644 .config/logs/2023.09.13/13.21.33.232311.log
#  create mode 100644 .config/logs/2023.09.13/13.21.58.423564.log
#  create mode 100644 .config/logs/2023.09.13/13.22.07.177764.log
#  create mode 100644 .config/logs/2023.09.13/13.22.33.105301.log
# ...
